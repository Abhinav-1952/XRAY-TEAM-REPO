# %% [markdown]
# # 03 — Model Experiments
# Owner: Modeling & Validation lead
#
# Compare model families and validation strategies here before finalizing `src/train.py`.

# %%
import sys
sys.path.append('../src')
import pandas as pd, numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Load precomputed feature table
# (Run the feature extraction loop from `src/train.py`'s `build_feature_table`, or cache it to a CSV first — don't recompute features on every notebook run.)

# %%
# TODO: load or build feature table

# %% [markdown]
# ## Compare model families
# Try at least 2 (e.g. RandomForest vs GradientBoosting vs LogisticRegression) and report per-class AUROC for each.

# %%
# TODO: fit + compare models

# %% [markdown]
# ## Threshold tuning per class
# Default 0.5 is a bad choice with 5–17% positive rates. Pick thresholds on validation data.

# %%
# TODO: tune per-class thresholds
